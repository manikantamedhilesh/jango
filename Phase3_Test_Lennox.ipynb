# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow
from matplotlib import pyplot as plt
from imutils.video import VideoStream
import numpy as np
import argparse
import imutils
import time
import dlib
import os
import pandas as pd

Phase="ph3"

# %%
import pandas as pd
df = pd.DataFrame(columns=[Phase+'Frameid',Phase+'bb',Phase+'Path_FrameId',Phase+'BB_Coordinates',Phase+'Path_to_BB_File',Phase+'CropFilePath'])
len(df)
# Out:
# 0

# %%
os.chdir('/content/drive/My Drive/Lennox/')
detector = dlib.simple_object_detector("/content/drive/My Drive/Lennox/Phase31Coil.dat")
imagesList=os.listdir('/content/drive/My Drive/Lennox/Phase3/Images/')
imagesList
# Out:
# ['frame532.jpg',
#  'frame591.jpg',
#  'frame945.jpg',
#  'frame2420.jpg',
#  'frame2715.jpg',
#  'frame2833.jpg',
#  'frame3836.jpg',
#  'frame4013.jpg',
#  'frame709.jpg',
#  'frame3128.jpg',
#  'frame4308.jpg',
#  'frame4249.jpg',
#  'frame4367.jpg']

# %%
# filename='/content/drive/My Drive/Lennox/Phase3/Images/frame532.jpg'
# filename.split("Lennox/")[1]

# %%
for i in imagesList:
  # filename='/content/drive/My Drive/Lennox/Images/'+i
  filename='/content/drive/My Drive/Lennox/Phase3/Images/'+i
  BBfilename='/content/drive/My Drive/Lennox/Phase3/Images_BB/'+i
  Resultfilename='/content/drive/My Drive/Lennox/Phase3/crop/'+i
  print(filename)
  image = cv2.imread(filename)
  print('Original Dimensions : ',image.shape)
  scale_percent = 95 # percent of original size
  width = int(image.shape[1] * scale_percent / 100)
  height = int(image.shape[0] * scale_percent / 100)
  dim = (width, height)
  # resize image
  resized = cv2.resize(image, dim, interpolation = cv2.INTER_AREA)
  print('Resized Dimensions : ',resized.shape)
  imgcopy = np.zeros(resized.shape[:3], np.uint8)##
  #imgcopy = np.zeros(image.shape[:3], np.uint8)##
  np.copyto(imgcopy, resized)## 


  detections = detector(resized)
  for k, d in enumerate(detections):
      print("Detection {}: Left: {} Top: {} Right: {} Bottom: {}".format(
            k, d.left(), d.top(), d.right(), d.bottom()))
      x,y,w,h = d.left(), d.top(), d.right(), d.bottom()
      print('Dlib Detections-',x,y,w,h)
      # cv2.rectangle(resized, (x, y), (w,h), [0,255,255], 2)
      # cv2_imshow(resized)

      crop=resized[y:h,x:w]
      # cv2_imshow(crop)
      CroppedFileName=Resultfilename.split(".")[0]+'_'+str(k)+'_'+Phase+'.jpg'
      print(CroppedFileName)
      cv2.imwrite(CroppedFileName,crop)
      
      imgcopy1 = np.zeros(resized.shape[:3], np.uint8)##
      np.copyto(imgcopy1, imgcopy)##
      cv2.rectangle(imgcopy1, (x, y), (w,h), [0,255,255], 2)##
      # cv2_imshow(imgcopy1)
      InterimBBImg=BBfilename.split(".")[0]+'_'+str(k)+'_'+Phase+'bb.jpg'
      cv2.imwrite(InterimBBImg,imgcopy1) ##
      print('InterimBBImg',InterimBBImg)

      cv2.rectangle(resized, (x, y), (w,h), [0,255,255], 2)
      # cv2_imshow(resized)
      FinalBBImg=BBfilename.split(".")[0]+'_'+Phase+'bb.jpg' ##     
      cv2.imwrite(FinalBBImg,resized)##
      print('FinalBBImg',FinalBBImg)
     
      # df.loc[len(df)]= [Phase,i.split(".")[0],filename.split("Lennox/")[1],[x,y,w,h],InterimBBImg.split("Lennox/")[1],CroppedFileName.split("Lennox/")[1]] ##
      df.loc[len(df)]= [i.split(".")[0],i.split(".")[0]+'_'+str(k)+'_'+Phase,filename.split("Lennox/")[1],[x,y,w,h],InterimBBImg.split("Lennox/")[1],CroppedFileName.split("Lennox/")[1]] ##
     

      # cv2.rectangle(resized, (x, y), (w,h), [0,255,255], 2)
      # # cv2_imshow(resized)      
      # cv2.imwrite(BBfilename.split(".")[0]+'_'+Phase+'bb.jpg',resized)
     
      # df.loc[len(df)]= [Phase,i.split(".")[0],filename.split("Lennox/")[1],[x,y,w,h],BBfilename.split("Lennox/")[1],CroppedFileName.split("Lennox/")[1]]
# Out:
# /content/drive/My Drive/Lennox/Phase3/Images/frame532.jpg
# Original Dimensions :  (1080, 1920, 3)
# Resized Dimensions :  (1026, 1824, 3)
# Detection 0: Left: 1506 Top: 61 Right: 1712 Bottom: 542
# Dlib Detections- 1506 61 1712 542
# /content/drive/My Drive/Lennox/Phase3/crop/frame532_0_ph3.jpg
# InterimBBImg /content/drive/My Drive/Lennox/Phase3/Images_BB/frame532_0_ph3bb.jpg
# FinalBBImg /content/drive/My Drive/Lennox/Phase3/Images_BB/frame532_ph3bb.jpg
# /content/drive/My Drive/Lennox/Phase3/Images/frame591.jpg
# Original Dimensions :  (1080, 1920, 3)
# Resized Dimensions :  (1026, 1824, 3)
# /content/drive/My Drive/Lennox/Phase3/Images/frame945.jpg
# Original Dimensions :  (1080, 1920, 3)
# Resized Dimensions :  (1026, 1824, 3)
# Detection 0: Left: 1609 Top: 26 Right: 1815 Bottom: 508
# Dlib Detections- 1609 26 1815 508
# /content/drive/My Drive/Lennox/Phase3/crop/frame945_0_ph3.jpg
# InterimBBImg /content/drive/My Drive/Lennox/Phase3/Images_BB/frame945_0_ph3bb.jpg
# FinalBBImg /content/drive/My Drive/Lennox/Phase3/Images_BB/frame945_ph3bb.jpg
# /content/drive/My Drive/Lennox/Phase3/Images/frame2420.jpg
# Original Dimensions :  (1080, 1920, 3)
# Resized Dimensions :  (1026, 1824, 3)
# /content/drive/My Drive/Lennox/Phase3/Images/frame2715.jpg
# Original Dimensions :  (1080, 1920, 3)
# Resized Dimensions :  (1026, 1824, 3)
# Detection 0: Left: 996 Top: 222 Right: 1168 Bottom: 624
# Dlib Detections- 996 222 1168 624
# /content/drive/My Drive/Lennox/Phase3/crop/frame2715_0_ph3.jpg
# InterimBBImg /content/drive/My Drive/Lennox/Phase3/Images_BB/frame2715_0_ph3bb.jpg
# FinalBBImg /content/drive/My Drive/Lennox/Phase3/Images_BB/frame2715_ph3bb.jpg
# /content/drive/My Drive/Lennox/Phase3/Images/frame2833.jpg
# Original Dimensions :  (1080, 1920, 3)
# Resized Dimensions :  (1026, 1824, 3)
# Detection 0: Left: 1254 Top: 222 Right: 1426 Bottom: 624
# Dlib Detections- 1254 222 1426 624
# /content/drive/My Drive/Lennox/Phase3/crop/frame2833_0_ph3.jpg
# InterimBBImg /content/drive/My Drive/Lennox/Phase3/Images_BB/frame2833_0_ph3bb.jpg
# FinalBBImg /content/drive/My Drive/Lennox/Phase3/Images_BB/frame2833_ph3bb.jpg
# /content/drive/My Drive/Lennox/Phase3/Images/frame3836.jpg
# Original Dimensions :  (1080, 1920, 3)
# Resized Dimensions :  (1026, 1824, 3)
# Detection 0: Left: 1312 Top: 136 Right: 1484 Bottom: 538
# Dlib Detections- 1312 136 1484 538
# /content/drive/My Drive/Lennox/Phase3/crop/frame3836_0_ph3.jpg
# InterimBBImg /content/drive/My Drive/Lennox/Phase3/Images_BB/frame3836_0_ph3bb.jpg
# FinalBBImg /content/drive/My Drive/Lennox/Phase3/Images_BB/frame3836_ph3bb.jpg
# Detection 1: Left: 1666 Top: 185 Right: 1809 Bottom: 520
# Dlib Detections- 1666 185 1809 520
# /content/drive/My Drive/Lennox/Phase3/crop/frame3836_1_ph3.jpg
# InterimBBImg /content/drive/My Drive/Lennox/Phase3/Images_BB/frame3836_1_ph3bb.jpg
# FinalBBImg /content/drive/My Drive/Lennox/Phase3/Images_BB/frame3836_ph3bb.jpg
# /content/drive/My Drive/Lennox/Phase3/Images/frame4013.jpg
# Original Dimensions :  (1080, 1920, 3)
# Resized Dimensions :  (1026, 1824, 3)
# Detection 0: Left: 854 Top: 233 Right: 997 Bottom: 567
# Dlib Detections- 854 233 997 567
# /content/drive/My Drive/Lennox/Phase3/crop/frame4013_0_ph3.jpg
# InterimBBImg /content/drive/My Drive/Lennox/Phase3/Images_BB/frame4013_0_ph3bb.jpg
# FinalBBImg /content/drive/My Drive/Lennox/Phase3/Images_BB/frame4013_ph3bb.jpg
# /content/drive/My Drive/Lennox/Phase3/Images/frame709.jpg
# Original Dimensions :  (1080, 1920, 3)
# Resized Dimensions :  (1026, 1824, 3)
# /content/drive/My Drive/Lennox/Phase3/Images/frame3128.jpg
# Original Dimensions :  (1080, 1920, 3)
# Resized Dimensions :  (1026, 1824, 3)
# Detection 0: Left: 1426 Top: 280 Right: 1598 Bottom: 681
# Dlib Detections- 1426 280 1598 681
# /content/drive/My Drive/Lennox/Phase3/crop/frame3128_0_ph3.jpg
# InterimBBImg /content/drive/My Drive/Lennox/Phase3/Images_BB/frame3128_0_ph3bb.jpg
# FinalBBImg /content/drive/My Drive/Lennox/Phase3/Images_BB/frame3128_ph3bb.jpg
# /content/drive/My Drive/Lennox/Phase3/Images/frame4308.jpg
# Original Dimensions :  (1080, 1920, 3)
# Resized Dimensions :  (1026, 1824, 3)
# Detection 0: Left: 955 Top: 336 Right: 1162 Bottom: 818
# Dlib Detections- 955 336 1162 818
# /content/drive/My Drive/Lennox/Phase3/crop/frame4308_0_ph3.jpg
# InterimBBImg /content/drive/My Drive/Lennox/Phase3/Images_BB/frame4308_0_ph3bb.jpg
# FinalBBImg /content/drive/My Drive/Lennox/Phase3/Images_BB/frame4308_ph3bb.jpg
# Detection 1: Left: 280 Top: 337 Right: 452 Bottom: 738
# Dlib Detections- 280 337 452 738
# /content/drive/My Drive/Lennox/Phase3/crop/frame4308_1_ph3.jpg
# InterimBBImg /content/drive/My Drive/Lennox/Phase3/Images_BB/frame4308_1_ph3bb.jpg
# FinalBBImg /content/drive/My Drive/Lennox/Phase3/Images_BB/frame4308_ph3bb.jpg
# /content/drive/My Drive/Lennox/Phase3/Images/frame4249.jpg
# Original Dimensions :  (1080, 1920, 3)
# Resized Dimensions :  (1026, 1824, 3)
# Detection 0: Left: 796 Top: 337 Right: 968 Bottom: 738
# Dlib Detections- 796 337 968 738
# /content/drive/My Drive/Lennox/Phase3/crop/frame4249_0_ph3.jpg
# InterimBBImg /content/drive/My Drive/Lennox/Phase3/Images_BB/frame4249_0_ph3bb.jpg
# FinalBBImg /content/drive/My Drive/Lennox/Phase3/Images_BB/frame4249_ph3bb.jpg
# Detection 1: Left: 136 Top: 308 Right: 308 Bottom: 710
# Dlib Detections- 136 308 308 710
# /content/drive/My Drive/Lennox/Phase3/crop/frame4249_1_ph3.jpg
# InterimBBImg /content/drive/My Drive/Lennox/Phase3/Images_BB/frame4249_1_ph3bb.jpg
# FinalBBImg /content/drive/My Drive/Lennox/Phase3/Images_BB/frame4249_ph3bb.jpg
# /content/drive/My Drive/Lennox/Phase3/Images/frame4367.jpg
# Original Dimensions :  (1080, 1920, 3)
# Resized Dimensions :  (1026, 1824, 3)
# Detection 0: Left: 921 Top: 302 Right: 1127 Bottom: 783
# Dlib Detections- 921 302 1127 783
# /content/drive/My Drive/Lennox/Phase3/crop/frame4367_0_ph3.jpg
# InterimBBImg /content/drive/My Drive/Lennox/Phase3/Images_BB/frame4367_0_ph3bb.jpg
# FinalBBImg /content/drive/My Drive/Lennox/Phase3/Images_BB/frame4367_ph3bb.jpg
# Detection 1: Left: 165 Top: 337 Right: 337 Bottom: 738
# Dlib Detections- 165 337 337 738
# /content/drive/My Drive/Lennox/Phase3/crop/frame4367_1_ph3.jpg
# InterimBBImg /content/drive/My Drive/Lennox/Phase3/Images_BB/frame4367_1_ph3bb.jpg
# FinalBBImg /content/drive/My Drive/Lennox/Phase3/Images_BB/frame4367_ph3bb.jpg

# %%
df.head(5)
# Out:
#   ph3Frameid  ...                  ph3CropFilePath
# 0   frame532  ...   Phase3/crop/frame532_0_ph3.jpg
# 1   frame945  ...   Phase3/crop/frame945_0_ph3.jpg
# 2  frame2715  ...  Phase3/crop/frame2715_0_ph3.jpg
# 3  frame2833  ...  Phase3/crop/frame2833_0_ph3.jpg
# 4  frame3836  ...  Phase3/crop/frame3836_0_ph3.jpg
#
# [5 rows x 6 columns]

# %%
df.to_csv('/content/drive/My Drive/Lennox/Phase3/'+'Phase3.csv')
