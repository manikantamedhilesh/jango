# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow
from matplotlib import pyplot as plt
from imutils.video import VideoStream
import numpy as np
import argparse
import imutils
import time
import dlib
import os
import pandas as pd
Phase="ph2"

# %%
import pandas as pd
df = pd.DataFrame(columns=[Phase+'Frameid',Phase+'bb',Phase+'Path_FrameId',Phase+'BB_Coordinates',Phase+'Path_to_BB_File',Phase+'CropFilePath'])
len(df)
# Out:
# 0

# %%
os.chdir('/content/drive/My Drive/Lennox/')
detector = dlib.simple_object_detector("/content/drive/My Drive/Lennox/Phase2Coil.dat")
imagesList=os.listdir('/content/drive/My Drive/Lennox/Phase2/Images/')
imagesList
# Out:
# ['frame119.jpg',
#  'frame355.jpg',
#  'frame2361.jpg',
#  'frame2302.jpg',
#  'frame4249.jpg',
#  'frame237.jpg',
#  'frame2125.jpg',
#  'frame2715.jpg',
#  'frame3895.jpg',
#  'frame9677.jpg',
#  'frame11742.jpg',
#  'frame11801.jpg',
#  'frame13512.jpg',
#  'frame14161.jpg',
#  'frame14220.jpg',
#  'frame14515.jpg',
#  'frame15341.jpg',
#  'frame16049.jpg',
#  'frame18822.jpg',
#  'frame20002.jpg',
#  'frame21064.jpg',
#  'frame21418.jpg',
#  'frame23955.jpg',
#  'frame24309.jpg',
#  'frame26551.jpg',
#  'frame26905.jpg']

# %%
for i in imagesList:
  # filename='/content/drive/My Drive/Lennox/Images/'+i
  filename='/content/drive/My Drive/Lennox/Phase2/Images/'+i
  BBfilename='/content/drive/My Drive/Lennox/Phase2/Images_BB/'+i
  Resultfilename='/content/drive/My Drive/Lennox/Phase2/crop/'+i
  print(filename)
  image = cv2.imread(filename)
  print('Original Dimensions : ',image.shape)
 
  scale_percent = 95 # percent of original size
  width = int(image.shape[1] * scale_percent / 100)
  height = int(image.shape[0] * scale_percent / 100)
  dim = (width, height)
  # resize image
  resized = cv2.resize(image, dim, interpolation = cv2.INTER_AREA)
  print('Resized Dimensions : ',resized.shape)

  imgcopy = np.zeros(resized.shape[:3], np.uint8)##
  #imgcopy = np.zeros(image.shape[:3], np.uint8)##
  np.copyto(imgcopy, resized)## 


  detections = detector(resized)
  for k, d in enumerate(detections):
      print("Detection {}: Left: {} Top: {} Right: {} Bottom: {}".format(
            k, d.left(), d.top(), d.right(), d.bottom()))
      x,y,w,h = d.left(), d.top(), d.right(), d.bottom()
      print('Dlib Detections-',x,y,w,h)
      # cv2.rectangle(resized, (x, y), (w,h), [0,255,255], 2)
      # cv2_imshow(resized)
      # crop=resized[y:h,x:w]

      # cv2_imshow(crop)
      # CroppedFileName=Resultfilename.split(".")[0]+Phase+'.jpg'
      # print(CroppedFileName)     
      # cv2.imwrite(CroppedFileName,crop)
      
      crop=resized[y:h,x:w]
      #cv2_imshow(crop)
      CroppedFileName=Resultfilename.split(".")[0]+'_'+str(k)+'_'+Phase+'.jpg'
      print(CroppedFileName)
      cv2.imwrite(CroppedFileName,crop)

      imgcopy1 = np.zeros(resized.shape[:3], np.uint8)##
      np.copyto(imgcopy1, imgcopy)##
      cv2.rectangle(imgcopy1, (x, y), (w,h), [0,255,255], 2)##
      # cv2_imshow(imgcopy1)
      InterimBBImg=BBfilename.split(".")[0]+'_'+str(k)+'_'+Phase+'bb.jpg'
      cv2.imwrite(InterimBBImg,imgcopy1) ##
      print('InterimBBImg',InterimBBImg)

      cv2.rectangle(resized, (x, y), (w,h), [0,255,255], 2)
      # cv2_imshow(resized)
      FinalBBImg=BBfilename.split(".")[0]+'_'+Phase+'bb.jpg' ##     
      cv2.imwrite(FinalBBImg,resized)##
      print('FinalBBImg',FinalBBImg)
     
      # df.loc[len(df)]= [Phase,i.split(".")[0],filename.split("Lennox/")[1],[x,y,w,h],InterimBBImg.split("Lennox/")[1],CroppedFileName.split("Lennox/")[1]] ##
      df.loc[len(df)]= [i.split(".")[0],i.split(".")[0]+'_'+str(k)+'_'+Phase,filename.split("Lennox/")[1],[x,y,w,h],InterimBBImg.split("Lennox/")[1],CroppedFileName.split("Lennox/")[1]] ##
     
      # cv2.rectangle(resized, (x, y), (w,h), [0,255,255], 2)
      # #cv2_imshow(resized)      
      # cv2.imwrite(BBfilename.split(".")[0]+'_'+Phase+'bb.jpg',resized)
     
      # df.loc[len(df)]= [Phase,i.split(".")[0],filename.split("Lennox/")[1],[x,y,w,h],BBfilename.split("Lennox/")[1],CroppedFileName.split("Lennox/")[1]]
# Out:
# /content/drive/My Drive/Lennox/Phase2/Images/frame119.jpg
# Original Dimensions :  (1080, 1920, 3)
# Resized Dimensions :  (1026, 1824, 3)
# Detection 0: Left: 342 Top: 342 Right: 1055 Bottom: 912
# Dlib Detections- 342 342 1055 912
# /content/drive/My Drive/Lennox/Phase2/crop/frame119_0_ph2.jpg
# InterimBBImg /content/drive/My Drive/Lennox/Phase2/Images_BB/frame119_0_ph2bb.jpg
# FinalBBImg /content/drive/My Drive/Lennox/Phase2/Images_BB/frame119_ph2bb.jpg
# /content/drive/My Drive/Lennox/Phase2/Images/frame355.jpg
# Original Dimensions :  (1080, 1920, 3)
# Resized Dimensions :  (1026, 1824, 3)
# Detection 0: Left: 325 Top: 154 Right: 1181 Bottom: 838
# Dlib Detections- 325 154 1181 838
# /content/drive/My Drive/Lennox/Phase2/crop/frame355_0_ph2.jpg
# InterimBBImg /content/drive/My Drive/Lennox/Phase2/Images_BB/frame355_0_ph2bb.jpg
# FinalBBImg /content/drive/My Drive/Lennox/Phase2/Images_BB/frame355_ph2bb.jpg
# /content/drive/My Drive/Lennox/Phase2/Images/frame2361.jpg
# Original Dimensions :  (1080, 1920, 3)
# Resized Dimensions :  (1026, 1824, 3)
# /content/drive/My Drive/Lennox/Phase2/Images/frame2302.jpg
# Original Dimensions :  (1080, 1920, 3)
# Resized Dimensions :  (1026, 1824, 3)
# Detection 0: Left: 47 Top: 344 Right: 641 Bottom: 820
# Dlib Detections- 47 344 641 820
# /content/drive/My Drive/Lennox/Phase2/crop/frame2302_0_ph2.jpg
# InterimBBImg /content/drive/My Drive/Lennox/Phase2/Images_BB/frame2302_0_ph2bb.jpg
# FinalBBImg /content/drive/My Drive/Lennox/Phase2/Images_BB/frame2302_ph2bb.jpg
# /content/drive/My Drive/Lennox/Phase2/Images/frame4249.jpg
# Original Dimensions :  (1080, 1920, 3)
# Resized Dimensions :  (1026, 1824, 3)
# Detection 0: Left: 582 Top: 239 Right: 1438 Bottom: 924
# Dlib Detections- 582 239 1438 924
# /content/drive/My Drive/Lennox/Phase2/crop/frame4249_0_ph2.jpg
# InterimBBImg /content/drive/My Drive/Lennox/Phase2/Images_BB/frame4249_0_ph2bb.jpg
# FinalBBImg /content/drive/My Drive/Lennox/Phase2/Images_BB/frame4249_ph2bb.jpg
# /content/drive/My Drive/Lennox/Phase2/Images/frame237.jpg
# Original Dimensions :  (1080, 1920, 3)
# Resized Dimensions :  (1026, 1824, 3)
# Detection 0: Left: 667 Top: 154 Right: 1523 Bottom: 838
# Dlib Detections- 667 154 1523 838
# /content/drive/My Drive/Lennox/Phase2/crop/frame237_0_ph2.jpg
# InterimBBImg /content/drive/My Drive/Lennox/Phase2/Images_BB/frame237_0_ph2bb.jpg
# FinalBBImg /content/drive/My Drive/Lennox/Phase2/Images_BB/frame237_ph2bb.jpg
# /content/drive/My Drive/Lennox/Phase2/Images/frame2125.jpg
# Original Dimensions :  (1080, 1920, 3)
# Resized Dimensions :  (1026, 1824, 3)
# Detection 0: Left: 770 Top: 556 Right: 1483 Bottom: 1126
# Dlib Detections- 770 556 1483 1126
# /content/drive/My Drive/Lennox/Phase2/crop/frame2125_0_ph2.jpg
# InterimBBImg /content/drive/My Drive/Lennox/Phase2/Images_BB/frame2125_0_ph2bb.jpg
# FinalBBImg /content/drive/My Drive/Lennox/Phase2/Images_BB/frame2125_ph2bb.jpg
# /content/drive/My Drive/Lennox/Phase2/Images/frame2715.jpg
# Original Dimensions :  (1080, 1920, 3)
# Resized Dimensions :  (1026, 1824, 3)
# /content/drive/My Drive/Lennox/Phase2/Images/frame3895.jpg
# Original Dimensions :  (1080, 1920, 3)
# Resized Dimensions :  (1026, 1824, 3)
# Detection 0: Left: 1198 Top: 484 Right: 1911 Bottom: 1055
# Dlib Detections- 1198 484 1911 1055
# /content/drive/My Drive/Lennox/Phase2/crop/frame3895_0_ph2.jpg
# InterimBBImg /content/drive/My Drive/Lennox/Phase2/Images_BB/frame3895_0_ph2bb.jpg
# FinalBBImg /content/drive/My Drive/Lennox/Phase2/Images_BB/frame3895_ph2bb.jpg
# /content/drive/My Drive/Lennox/Phase2/Images/frame9677.jpg
# Original Dimensions :  (1080, 1920, 3)
# Resized Dimensions :  (1026, 1824, 3)
# Detection 0: Left: 285 Top: 225 Right: 879 Bottom: 701
# Dlib Detections- 285 225 879 701
# /content/drive/My Drive/Lennox/Phase2/crop/frame9677_0_ph2.jpg
# InterimBBImg /content/drive/My Drive/Lennox/Phase2/Images_BB/frame9677_0_ph2bb.jpg
# FinalBBImg /content/drive/My Drive/Lennox/Phase2/Images_BB/frame9677_ph2bb.jpg
# /content/drive/My Drive/Lennox/Phase2/Images/frame11742.jpg
# Original Dimensions :  (1080, 1920, 3)
# Resized Dimensions :  (1026, 1824, 3)
# Detection 0: Left: 342 Top: 128 Right: 1055 Bottom: 698
# Dlib Detections- 342 128 1055 698
# /content/drive/My Drive/Lennox/Phase2/crop/frame11742_0_ph2.jpg
# InterimBBImg /content/drive/My Drive/Lennox/Phase2/Images_BB/frame11742_0_ph2bb.jpg
# FinalBBImg /content/drive/My Drive/Lennox/Phase2/Images_BB/frame11742_ph2bb.jpg
# /content/drive/My Drive/Lennox/Phase2/Images/frame11801.jpg
# Original Dimensions :  (1080, 1920, 3)
# Resized Dimensions :  (1026, 1824, 3)
# Detection 0: Left: 342 Top: 128 Right: 1055 Bottom: 698
# Dlib Detections- 342 128 1055 698
# /content/drive/My Drive/Lennox/Phase2/crop/frame11801_0_ph2.jpg
# InterimBBImg /content/drive/My Drive/Lennox/Phase2/Images_BB/frame11801_0_ph2bb.jpg
# FinalBBImg /content/drive/My Drive/Lennox/Phase2/Images_BB/frame11801_ph2bb.jpg
# /content/drive/My Drive/Lennox/Phase2/Images/frame13512.jpg
# Original Dimensions :  (1080, 1920, 3)
# Resized Dimensions :  (1026, 1824, 3)
# Detection 0: Left: 841 Top: 270 Right: 1554 Bottom: 841
# Dlib Detections- 841 270 1554 841
# /content/drive/My Drive/Lennox/Phase2/crop/frame13512_0_ph2.jpg
# InterimBBImg /content/drive/My Drive/Lennox/Phase2/Images_BB/frame13512_0_ph2bb.jpg
# FinalBBImg /content/drive/My Drive/Lennox/Phase2/Images_BB/frame13512_ph2bb.jpg
# /content/drive/My Drive/Lennox/Phase2/Images/frame14161.jpg
# Original Dimensions :  (1080, 1920, 3)
# Resized Dimensions :  (1026, 1824, 3)
# Detection 0: Left: 556 Top: 199 Right: 1269 Bottom: 770
# Dlib Detections- 556 199 1269 770
# /content/drive/My Drive/Lennox/Phase2/crop/frame14161_0_ph2.jpg
# InterimBBImg /content/drive/My Drive/Lennox/Phase2/Images_BB/frame14161_0_ph2bb.jpg
# FinalBBImg /content/drive/My Drive/Lennox/Phase2/Images_BB/frame14161_ph2bb.jpg
# /content/drive/My Drive/Lennox/Phase2/Images/frame14220.jpg
# Original Dimensions :  (1080, 1920, 3)
# Resized Dimensions :  (1026, 1824, 3)
# /content/drive/My Drive/Lennox/Phase2/Images/frame14515.jpg
# Original Dimensions :  (1080, 1920, 3)
# Resized Dimensions :  (1026, 1824, 3)
# /content/drive/My Drive/Lennox/Phase2/Images/frame15341.jpg
# Original Dimensions :  (1080, 1920, 3)
# Resized Dimensions :  (1026, 1824, 3)
# Detection 0: Left: 912 Top: 128 Right: 1626 Bottom: 698
# Dlib Detections- 912 128 1626 698
# /content/drive/My Drive/Lennox/Phase2/crop/frame15341_0_ph2.jpg
# InterimBBImg /content/drive/My Drive/Lennox/Phase2/Images_BB/frame15341_0_ph2bb.jpg
# FinalBBImg /content/drive/My Drive/Lennox/Phase2/Images_BB/frame15341_ph2bb.jpg
# /content/drive/My Drive/Lennox/Phase2/Images/frame16049.jpg
# Original Dimensions :  (1080, 1920, 3)
# Resized Dimensions :  (1026, 1824, 3)
# Detection 0: Left: 912 Top: 270 Right: 1626 Bottom: 841
# Dlib Detections- 912 270 1626 841
# /content/drive/My Drive/Lennox/Phase2/crop/frame16049_0_ph2.jpg
# InterimBBImg /content/drive/My Drive/Lennox/Phase2/Images_BB/frame16049_0_ph2bb.jpg
# FinalBBImg /content/drive/My Drive/Lennox/Phase2/Images_BB/frame16049_ph2bb.jpg
# /content/drive/My Drive/Lennox/Phase2/Images/frame18822.jpg
# Original Dimensions :  (1080, 1920, 3)
# Resized Dimensions :  (1026, 1824, 3)
# Detection 0: Left: 556 Top: 199 Right: 1269 Bottom: 770
# Dlib Detections- 556 199 1269 770
# /content/drive/My Drive/Lennox/Phase2/crop/frame18822_0_ph2.jpg
# InterimBBImg /content/drive/My Drive/Lennox/Phase2/Images_BB/frame18822_0_ph2bb.jpg
# FinalBBImg /content/drive/My Drive/Lennox/Phase2/Images_BB/frame18822_ph2bb.jpg
# /content/drive/My Drive/Lennox/Phase2/Images/frame20002.jpg
# Original Dimensions :  (1080, 1920, 3)
# Resized Dimensions :  (1026, 1824, 3)
# Detection 0: Left: 1055 Top: 128 Right: 1768 Bottom: 698
# Dlib Detections- 1055 128 1768 698
# /content/drive/My Drive/Lennox/Phase2/crop/frame20002_0_ph2.jpg
# InterimBBImg /content/drive/My Drive/Lennox/Phase2/Images_BB/frame20002_0_ph2bb.jpg
# FinalBBImg /content/drive/My Drive/Lennox/Phase2/Images_BB/frame20002_ph2bb.jpg
# /content/drive/My Drive/Lennox/Phase2/Images/frame21064.jpg
# Original Dimensions :  (1080, 1920, 3)
# Resized Dimensions :  (1026, 1824, 3)
# Detection 0: Left: 820 Top: 344 Right: 1414 Bottom: 820
# Dlib Detections- 820 344 1414 820
# /content/drive/My Drive/Lennox/Phase2/crop/frame21064_0_ph2.jpg
# InterimBBImg /content/drive/My Drive/Lennox/Phase2/Images_BB/frame21064_0_ph2bb.jpg
# FinalBBImg /content/drive/My Drive/Lennox/Phase2/Images_BB/frame21064_ph2bb.jpg
# /content/drive/My Drive/Lennox/Phase2/Images/frame21418.jpg
# Original Dimensions :  (1080, 1920, 3)
# Resized Dimensions :  (1026, 1824, 3)
# Detection 0: Left: 641 Top: 285 Right: 1236 Bottom: 760
# Dlib Detections- 641 285 1236 760
# /content/drive/My Drive/Lennox/Phase2/crop/frame21418_0_ph2.jpg
# InterimBBImg /content/drive/My Drive/Lennox/Phase2/Images_BB/frame21418_0_ph2bb.jpg
# FinalBBImg /content/drive/My Drive/Lennox/Phase2/Images_BB/frame21418_ph2bb.jpg
# /content/drive/My Drive/Lennox/Phase2/Images/frame23955.jpg
# Original Dimensions :  (1080, 1920, 3)
# Resized Dimensions :  (1026, 1824, 3)
# Detection 0: Left: 841 Top: 128 Right: 1554 Bottom: 698
# Dlib Detections- 841 128 1554 698
# /content/drive/My Drive/Lennox/Phase2/crop/frame23955_0_ph2.jpg
# InterimBBImg /content/drive/My Drive/Lennox/Phase2/Images_BB/frame23955_0_ph2bb.jpg
# FinalBBImg /content/drive/My Drive/Lennox/Phase2/Images_BB/frame23955_ph2bb.jpg
# /content/drive/My Drive/Lennox/Phase2/Images/frame24309.jpg
# Original Dimensions :  (1080, 1920, 3)
# Resized Dimensions :  (1026, 1824, 3)
# /content/drive/My Drive/Lennox/Phase2/Images/frame26551.jpg
# Original Dimensions :  (1080, 1920, 3)
# Resized Dimensions :  (1026, 1824, 3)
# Detection 0: Left: 344 Top: 106 Right: 938 Bottom: 582
# Dlib Detections- 344 106 938 582
# /content/drive/My Drive/Lennox/Phase2/crop/frame26551_0_ph2.jpg
# InterimBBImg /content/drive/My Drive/Lennox/Phase2/Images_BB/frame26551_0_ph2bb.jpg
# FinalBBImg /content/drive/My Drive/Lennox/Phase2/Images_BB/frame26551_ph2bb.jpg
# /content/drive/My Drive/Lennox/Phase2/Images/frame26905.jpg
# Original Dimensions :  (1080, 1920, 3)
# Resized Dimensions :  (1026, 1824, 3)
# Detection 0: Left: 413 Top: 56 Right: 1126 Bottom: 627
# Dlib Detections- 413 56 1126 627
# /content/drive/My Drive/Lennox/Phase2/crop/frame26905_0_ph2.jpg
# InterimBBImg /content/drive/My Drive/Lennox/Phase2/Images_BB/frame26905_0_ph2bb.jpg
# FinalBBImg /content/drive/My Drive/Lennox/Phase2/Images_BB/frame26905_ph2bb.jpg

# %%
df.head(5)
# Out:
#   ph2Frameid  ...                  ph2CropFilePath
# 0   frame119  ...   Phase2/crop/frame119_0_ph2.jpg
# 1   frame355  ...   Phase2/crop/frame355_0_ph2.jpg
# 2  frame2302  ...  Phase2/crop/frame2302_0_ph2.jpg
# 3  frame4249  ...  Phase2/crop/frame4249_0_ph2.jpg
# 4   frame237  ...   Phase2/crop/frame237_0_ph2.jpg
#
# [5 rows x 6 columns]

# %%
df.to_csv('/content/drive/My Drive/Lennox/Phase2/'+'Phase2.csv')
