# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow
from matplotlib import pyplot as plt
from imutils.video import VideoStream
import numpy as np
import argparse
import imutils
import time
import dlib
import os
Phase='ph4'

# %%
import pandas as pd
df = pd.DataFrame(columns=[Phase+'Frameid',Phase+'bb',Phase+'Path_FrameId',Phase+'BB_Coordinates',Phase+'Path_to_BB_File',Phase+'CropFilePath'])
len(df)
# Out:
# 0

# %%
os.chdir('/content/drive/My Drive/Lennox/')
detector = dlib.simple_object_detector("/content/drive/My Drive/Lennox/Phase4Coil.dat")
imagesList=os.listdir('/content/drive/My Drive/Lennox/Phase4/Images')
imagesList
# Out:
# ['frame2420.jpg',
#  'frame4249.jpg',
#  'frame4544.jpg',
#  'frame4839.jpg',
#  'frame5252.jpg',
#  'frame6314.jpg',
#  'frame3364.jpg',
#  'frame3600.jpg',
#  'frame3541.jpg',
#  'frame10444.jpg',
#  'frame10503.jpg',
#  'frame10562.jpg']

# %%
# filename='/content/drive/My Drive/Lennox/Phase4/Images/frame10562.jpg'
# image = cv2.imread(filename)
# imgcopy = np.zeros(image.shape[:3], np.uint8)##
# np.copyto(imgcopy, image) 
# 1656 394 1828 738
# cv2.rectangle(imgcopy, (1656, 394), (1828,738), [0,255,255], 2)
# cv2.putText(imgcopy, 'testing', (1684 , int(1856)), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 0, 255), 1, cv2.LINE_AA)
# cv2_imshow(image)
# plt.imshow(image)
#

# %%
# plt.imshow(imgcopy)
# cv2_imshow(imgcopy)

# %%
# plt.imshow(imgcopy)

# %%
for i in imagesList:
  # filename='/content/drive/My Drive/Lennox/Images/'+i
  filename='/content/drive/My Drive/Lennox/Phase4/Images/'+i
  BBfilename='/content/drive/My Drive/Lennox/Phase4/Images_BB/'+i
  Resultfilename='/content/drive/My Drive/Lennox/Phase4/crop/'+i
  image = cv2.imread(filename)
  print('Original Dimensions : ',image.shape)
 
  scale_percent = 95 # percent of original size
  width = int(image.shape[1] * scale_percent / 100)
  height = int(image.shape[0] * scale_percent / 100)
  dim = (width, height)
  # resize image
  resized = cv2.resize(image, dim, interpolation = cv2.INTER_AREA)
  print('Resized Dimensions : ',resized.shape)
  imgcopy = np.zeros(resized.shape[:3], np.uint8)##
  #imgcopy = np.zeros(image.shape[:3], np.uint8)##
  np.copyto(imgcopy, resized)## 

  detections = detector(resized)
  for k, d in enumerate(detections):
      print("Detection {}: Left: {} Top: {} Right: {} Bottom: {}".format(
            k, d.left(), d.top(), d.right(), d.bottom()))
      x,y,w,h = d.left(), d.top(), d.right(), d.bottom()
      print('Dlib Detections-',x,y,w,h)
      # cv2.rectangle(resized, (x, y), (w,h), [0,255,255], 2)
      # cv2_imshow(resized)
      # crop=resized[y:h,x:w]
      # cv2_imshow(crop)
      # CroppedFileName=Resultfilename.split(".")[0]+Phase+'.jpg'
      # print(CroppedFileName)     
      # cv2.imwrite(CroppedFileName,crop)  
      crop=resized[y:h,x:w]

      # cv2_imshow(crop)
      CroppedFileName=Resultfilename.split(".")[0]+'_'+str(k)+'_'+Phase+'.jpg'
      # print(CroppedFileName)
      cv2.imwrite(CroppedFileName,crop)
      
      imgcopy1 = np.zeros(resized.shape[:3], np.uint8)##
      np.copyto(imgcopy1, imgcopy)##
      cv2.rectangle(imgcopy1, (x, y), (w,h), [0,255,255], 2)##
      # cv2_imshow(imgcopy1)
      InterimBBImg=BBfilename.split(".")[0]+'_'+str(k)+'_'+Phase+'bb.jpg'
      cv2.imwrite(InterimBBImg,imgcopy1) ##
      print('InterimBBImg',InterimBBImg)

      cv2.rectangle(resized, (x, y), (w,h), [0,255,255], 2)
      # cv2_imshow(resized)
      FinalBBImg=BBfilename.split(".")[0]+'_'+Phase+'bb.jpg' ##     
      cv2.imwrite(FinalBBImg,resized)##
      print('FinalBBImg',FinalBBImg)
      print(i.split(".")[0]+'_'+str(k)+'_'+Phase) 
      df.loc[len(df)]= [i.split(".")[0],i.split(".")[0]+'_'+str(k)+'_'+Phase,filename.split("Lennox/")[1],[x,y,w,h],InterimBBImg.split("Lennox/")[1],CroppedFileName.split("Lennox/")[1]] ##
      
    
      #cv2.imwrite('testing'+str(count+1)+'.png',image)
# Out:
# Original Dimensions :  (1080, 1920, 3)
# Resized Dimensions :  (1026, 1824, 3)
# Detection 0: Left: 1656 Top: 394 Right: 1828 Bottom: 738
# Dlib Detections- 1656 394 1828 738
# InterimBBImg /content/drive/My Drive/Lennox/Phase4/Images_BB/frame2420_0_ph4bb.jpg
# FinalBBImg /content/drive/My Drive/Lennox/Phase4/Images_BB/frame2420_ph4bb.jpg
# frame2420_0_ph4
# Original Dimensions :  (1080, 1920, 3)
# Resized Dimensions :  (1026, 1824, 3)
# Detection 0: Left: 1570 Top: 337 Right: 1742 Bottom: 681
# Dlib Detections- 1570 337 1742 681
# InterimBBImg /content/drive/My Drive/Lennox/Phase4/Images_BB/frame4249_0_ph4bb.jpg
# FinalBBImg /content/drive/My Drive/Lennox/Phase4/Images_BB/frame4249_ph4bb.jpg
# frame4249_0_ph4
# Detection 1: Left: 233 Top: 302 Right: 439 Bottom: 714
# Dlib Detections- 233 302 439 714
# InterimBBImg /content/drive/My Drive/Lennox/Phase4/Images_BB/frame4249_1_ph4bb.jpg
# FinalBBImg /content/drive/My Drive/Lennox/Phase4/Images_BB/frame4249_ph4bb.jpg
# frame4249_1_ph4
# Original Dimensions :  (1080, 1920, 3)
# Resized Dimensions :  (1026, 1824, 3)
# Detection 0: Left: 164 Top: 336 Right: 370 Bottom: 749
# Dlib Detections- 164 336 370 749
# InterimBBImg /content/drive/My Drive/Lennox/Phase4/Images_BB/frame4544_0_ph4bb.jpg
# FinalBBImg /content/drive/My Drive/Lennox/Phase4/Images_BB/frame4544_ph4bb.jpg
# frame4544_0_ph4
# Detection 1: Left: 1512 Top: 366 Right: 1684 Bottom: 710
# Dlib Detections- 1512 366 1684 710
# InterimBBImg /content/drive/My Drive/Lennox/Phase4/Images_BB/frame4544_1_ph4bb.jpg
# FinalBBImg /content/drive/My Drive/Lennox/Phase4/Images_BB/frame4544_ph4bb.jpg
# frame4544_1_ph4
# Original Dimensions :  (1080, 1920, 3)
# Resized Dimensions :  (1026, 1824, 3)
# Detection 0: Left: 1512 Top: 337 Right: 1684 Bottom: 681
# Dlib Detections- 1512 337 1684 681
# InterimBBImg /content/drive/My Drive/Lennox/Phase4/Images_BB/frame4839_0_ph4bb.jpg
# FinalBBImg /content/drive/My Drive/Lennox/Phase4/Images_BB/frame4839_ph4bb.jpg
# frame4839_0_ph4
# Detection 1: Left: 164 Top: 302 Right: 370 Bottom: 714
# Dlib Detections- 164 302 370 714
# InterimBBImg /content/drive/My Drive/Lennox/Phase4/Images_BB/frame4839_1_ph4bb.jpg
# FinalBBImg /content/drive/My Drive/Lennox/Phase4/Images_BB/frame4839_ph4bb.jpg
# frame4839_1_ph4
# Original Dimensions :  (1080, 1920, 3)
# Resized Dimensions :  (1026, 1824, 3)
# Detection 0: Left: 1512 Top: 366 Right: 1684 Bottom: 710
# Dlib Detections- 1512 366 1684 710
# InterimBBImg /content/drive/My Drive/Lennox/Phase4/Images_BB/frame5252_0_ph4bb.jpg
# FinalBBImg /content/drive/My Drive/Lennox/Phase4/Images_BB/frame5252_ph4bb.jpg
# frame5252_0_ph4
# Detection 1: Left: 1116 Top: 507 Right: 1199 Bottom: 673
# Dlib Detections- 1116 507 1199 673
# InterimBBImg /content/drive/My Drive/Lennox/Phase4/Images_BB/frame5252_1_ph4bb.jpg
# FinalBBImg /content/drive/My Drive/Lennox/Phase4/Images_BB/frame5252_ph4bb.jpg
# frame5252_1_ph4
# Original Dimensions :  (1080, 1920, 3)
# Resized Dimensions :  (1026, 1824, 3)
# Detection 0: Left: 1512 Top: 222 Right: 1684 Bottom: 566
# Dlib Detections- 1512 222 1684 566
# InterimBBImg /content/drive/My Drive/Lennox/Phase4/Images_BB/frame6314_0_ph4bb.jpg
# FinalBBImg /content/drive/My Drive/Lennox/Phase4/Images_BB/frame6314_ph4bb.jpg
# frame6314_0_ph4
# Detection 1: Left: 577 Top: 233 Right: 783 Bottom: 646
# Dlib Detections- 577 233 783 646
# InterimBBImg /content/drive/My Drive/Lennox/Phase4/Images_BB/frame6314_1_ph4bb.jpg
# FinalBBImg /content/drive/My Drive/Lennox/Phase4/Images_BB/frame6314_ph4bb.jpg
# frame6314_1_ph4
# Detection 2: Left: 130 Top: 233 Right: 336 Bottom: 646
# Dlib Detections- 130 233 336 646
# InterimBBImg /content/drive/My Drive/Lennox/Phase4/Images_BB/frame6314_2_ph4bb.jpg
# FinalBBImg /content/drive/My Drive/Lennox/Phase4/Images_BB/frame6314_ph4bb.jpg
# frame6314_2_ph4
# Original Dimensions :  (1080, 1920, 3)
# Resized Dimensions :  (1026, 1824, 3)
# Detection 0: Left: 1656 Top: 423 Right: 1828 Bottom: 767
# Dlib Detections- 1656 423 1828 767
# InterimBBImg /content/drive/My Drive/Lennox/Phase4/Images_BB/frame3364_0_ph4bb.jpg
# FinalBBImg /content/drive/My Drive/Lennox/Phase4/Images_BB/frame3364_ph4bb.jpg
# frame3364_0_ph4
# Original Dimensions :  (1080, 1920, 3)
# Resized Dimensions :  (1026, 1824, 3)
# Detection 0: Left: 1598 Top: 394 Right: 1770 Bottom: 738
# Dlib Detections- 1598 394 1770 738
# InterimBBImg /content/drive/My Drive/Lennox/Phase4/Images_BB/frame3600_0_ph4bb.jpg
# FinalBBImg /content/drive/My Drive/Lennox/Phase4/Images_BB/frame3600_ph4bb.jpg
# frame3600_0_ph4
# Original Dimensions :  (1080, 1920, 3)
# Resized Dimensions :  (1026, 1824, 3)
# Detection 0: Left: 1598 Top: 423 Right: 1770 Bottom: 767
# Dlib Detections- 1598 423 1770 767
# InterimBBImg /content/drive/My Drive/Lennox/Phase4/Images_BB/frame3541_0_ph4bb.jpg
# FinalBBImg /content/drive/My Drive/Lennox/Phase4/Images_BB/frame3541_ph4bb.jpg
# frame3541_0_ph4
# Original Dimensions :  (1080, 1920, 3)
# Resized Dimensions :  (1026, 1824, 3)
# Detection 0: Left: 198 Top: 302 Right: 405 Bottom: 714
# Dlib Detections- 198 302 405 714
# InterimBBImg /content/drive/My Drive/Lennox/Phase4/Images_BB/frame10444_0_ph4bb.jpg
# FinalBBImg /content/drive/My Drive/Lennox/Phase4/Images_BB/frame10444_ph4bb.jpg
# frame10444_0_ph4
# Detection 1: Left: 1283 Top: 337 Right: 1455 Bottom: 681
# Dlib Detections- 1283 337 1455 681
# InterimBBImg /content/drive/My Drive/Lennox/Phase4/Images_BB/frame10444_1_ph4bb.jpg
# FinalBBImg /content/drive/My Drive/Lennox/Phase4/Images_BB/frame10444_ph4bb.jpg
# frame10444_1_ph4
# Detection 2: Left: 1684 Top: 337 Right: 1856 Bottom: 681
# Dlib Detections- 1684 337 1856 681
# InterimBBImg /content/drive/My Drive/Lennox/Phase4/Images_BB/frame10444_2_ph4bb.jpg
# FinalBBImg /content/drive/My Drive/Lennox/Phase4/Images_BB/frame10444_ph4bb.jpg
# frame10444_2_ph4
# Original Dimensions :  (1080, 1920, 3)
# Resized Dimensions :  (1026, 1824, 3)
# Detection 0: Left: 1283 Top: 337 Right: 1455 Bottom: 681
# Dlib Detections- 1283 337 1455 681
# InterimBBImg /content/drive/My Drive/Lennox/Phase4/Images_BB/frame10503_0_ph4bb.jpg
# FinalBBImg /content/drive/My Drive/Lennox/Phase4/Images_BB/frame10503_ph4bb.jpg
# frame10503_0_ph4
# Detection 1: Left: 1684 Top: 337 Right: 1856 Bottom: 681
# Dlib Detections- 1684 337 1856 681
# InterimBBImg /content/drive/My Drive/Lennox/Phase4/Images_BB/frame10503_1_ph4bb.jpg
# FinalBBImg /content/drive/My Drive/Lennox/Phase4/Images_BB/frame10503_ph4bb.jpg
# frame10503_1_ph4
# Original Dimensions :  (1080, 1920, 3)
# Resized Dimensions :  (1026, 1824, 3)
# Detection 0: Left: 233 Top: 302 Right: 439 Bottom: 714
# Dlib Detections- 233 302 439 714
# InterimBBImg /content/drive/My Drive/Lennox/Phase4/Images_BB/frame10562_0_ph4bb.jpg
# FinalBBImg /content/drive/My Drive/Lennox/Phase4/Images_BB/frame10562_ph4bb.jpg
# frame10562_0_ph4

# %%
df.head(5)
# Out:
#   ph4Frameid  ...                  ph4CropFilePath
# 0  frame2420  ...  Phase4/crop/frame2420_0_ph4.jpg
# 1  frame4249  ...  Phase4/crop/frame4249_0_ph4.jpg
# 2  frame4249  ...  Phase4/crop/frame4249_1_ph4.jpg
# 3  frame4544  ...  Phase4/crop/frame4544_0_ph4.jpg
# 4  frame4544  ...  Phase4/crop/frame4544_1_ph4.jpg
#
# [5 rows x 6 columns]

# %%
df.shape
# Out:
# (21, 6)

# %%
df.to_csv('/content/drive/My Drive/Lennox/Phase4/'+'Phase4.csv')
